# %% [markdown]
# # Données multimédia : Python pour le traitement d’images et de données audio
#
# ## Master Humanités Numériques du [CESR](https://cesr.univ-tours.fr/)
#
# Clément Plancq (MSH VDL / CITERES)

# %% [markdown]
# - Pas un cours de traitement d’image ou de traitement du signal
#     - [Supports de cours de Frédéric Legrand](https://www.f-legrand.fr/scidoc/)
#     - [Basics of Image Processing — Vincent Mazet (Université de Strasbourg)](https://www.f-legrand.fr/scidoc/)
#     - [Supports de *Digital Image Processing* (Stanford)](https://web.stanford.edu/class/ee368/handouts.html)
# - Pas un cours de python
#     - vous avez déjà un cours de Python
#     - [Mooc sur la plateforme FUN](https://www.fun-mooc.fr/fr/cours/python-3-des-fondamentaux-aux-concepts-avances-du-langage/)
#     - [Google’s Python Class](https://developers.google.com/edu/python)
# - Python appliqué au traitement d’images et de données audio

# %% [markdown]
# ## Python appliqué au traitement d’images et de données audio
#
# Logiciels avec interface graphique (GUI) :
#  [Photoshop (Adobe)](https://www.adobe.com/fr/products/photoshop.html) <img alt="logo photoshop" src="https://logos-world.net/wp-content/uploads/2020/11/Adobe-Photoshop-Logo-2013-2015.png" width="100" height="100" style="display:inline;"/>
#  [Gimp](https://www.gimp.org/) <img alt="logo gimp" src="https://www.gimp.org/images/frontpage/wilber-big.png" width="100" height="100" style="display:inline;"/>
#  [XnView](https://www.xnview.com/fr/) <img alt="loge xnview" src="https://www.xnview.com/img/app-xnsoft-360.webp" width="100" height="100" style="display:inline;"/>
#  [Audacity](https://www.audacityteam.org/) <img alt="logo audacity" src="https://www.audacityteam.org/_astro/Audacity_Logo.DK8H7nvr.svg" width="100" height="100" style="display:inline;"/>
#  [Ableton](https://www.ableton.com/) <img alt="logo ableton" src="https://www.logosvgpng.com/wp-content/uploads/2018/02/ableton-logo-vector.png" width="100" height="100" style="display:inline;"/>
#  [Garage Band (Apple)](https://www.apple.com/fr/mac/garageband/) <img alt="logo garage band" src="https://vignette.wikia.nocookie.net/logopedia/images/6/63/GarageBand2013AppIcon.jpg/revision/latest?cb=20170930112051" width="100" height="100" style="display:inline;"/>

# %% [markdown]
# ## Python appliqué au traitement d’images et de données audio
#
# Logiciels avec interface en ligne de commande (CLI) :
#
# [ffmpeg](https://ffmpeg.org/) <img alt="logo ffmpeg" src="https://upload.wikimedia.org/wikipedia/commons/5/5f/FFmpeg_Logo_new.svg" width="100" height="100"  style="display:inline;"/>
#
# [ImageMagick](https://imagemagick.org/)<img alt="logo image magick" src="https://imagemagick.org/image/wand.ico" width="100" height="100"  style="display:inline;"/>

# %% [markdown]
# ## Python appliqué au traitement d’images et de données audio
#
# Quels sont les avantages par rapport à un logiciel (GUI ou CLI) ?
#
#  1. Automatisation : en écrivant des scripts vous pouvez répéter des opérations (filtre, découpe, conversion) sur un grand nombre de fichiers sans intervention manuelle (les logiciels peuvent aussi faire du traitement par lot)
#
#  2. Personnalisation : vous avez accès à plus de paramètres pour manipuler les algorithmes (les filtres par exemple) et vous pouvez les combiner à votre guise
#
#  3. Intégration : vous pouvez intégrer des traitements dans une application, un site ou une chaîne de traitement

# %% [markdown]
# ## Python appliqué au traitement d’images et de données audio
#
# Quels sont les avantages par rapport à un logiciel (GUI ou CLI) ?
#
#  4. Performance : Python n’est pas réputé pour sa rapidité. Néanmoins un script bien conçu pourra être moins gourmand en ressource que l’utilisation d’un logiciel
#
#  5. Ressources communautaires : vous trouverez beaucoup de documentation, de tutoriels et d’aide auprès de la communauté d’utilisateurs Python
#
#  6. Portabilité : vos scripts Python fonctionneront sur les OS les plus courants (Linux, Mac OS, Windows)
#
#  7. Savoir : programmer vous aidera à appréhender les concepts de traitement du signal et vous vous améliorerez en Python 🐍

# %% [markdown]
# ## Python appliqué au traitement d’images et de données audio
#
# Et les inconvénients ?
#
#  1. C’est certainement plus compliqué et plus long d’apprendre à écrire un script que d’apprendre à utiliser un logiciel avec interface graphique
#  2. Le manque de visualisation est un inconvénient. Sans représentation graphique ou sonore c’est plus difficile de comprendre et d’améliorer ce qu’on fait
#  2. Vous pourrez partager vos scripts mais ils n’auront pas d’interface graphique. Et les seules visualisations seront celles que vous aurez écrites

# %% [markdown]
# Un exemple simple de traitement d’image qu’on peut faire avec Python : flouter une partie d’image

# %%
from IPython.display import Image, display

image_url = 'https://cesr.univ-tours.fr/medias/photo/cpr-1130x400_1521210968998-jpg'
# une image de https://cesr.univ-tours.fr/centre-detudes-superieures-de-la-renaissance/master-cultures-et-patrimoines-de-la-renaissance
display(Image(url=image_url))
# Out:
# <img src="https://cesr.univ-tours.fr/medias/photo/cpr-1130x400_1521210968998-jpg"/>

# %% [markdown]
# Pour flouter on va utiliser le module [Pillow](https://python-pillow.org/)
# Pour simplifier on va travailler avec un fichier image et pas une url

# %%
# import Pillow library
from PIL import Image, ImageFilter

image = Image.open('../img/CPR_1130x400.jpg') # 'image' est un objet de la classe Image
#display(image)

# %% [markdown]
# Une fois en mémoire on peut appliquer le filtre *blur* sur une partie de l’image (voir la [doc](https://pillow.readthedocs.io/en/stable/reference/ImageFilter.html), toujours voir la doc)

# %%
box = (185, 25, 335, 175) # on définit la partie à flouter avec ses coordonnées (left, top, right, bottom)
region = image.crop(box) # hop on découpe la partie
blurred_region = region.filter(ImageFilter.BoxBlur(10)) # Blur pas Oasis
image.paste(blurred_region, box) # on copie la partie floutée

display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1130x400>

# %% [markdown]
# ## Python
#
# Le langage Python a été créé par Guido Van Rossum en 1991
#
# C’est un langage interprété, de haut niveau, multiplateformes, sous licence libre (voir [le code source](https://github.com/python/cpython))
#
# ![Guido](https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Guido_van_Rossum_OSCON_2006.jpg/400px-Guido_van_Rossum_OSCON_2006.jpg)

# %% [markdown]
# | Python      | C           |
# | ----------- | ----------- |
# | 1991        | 1972 |
# | interprété  | compilé       |
# | multiplateforme   | non        |
# | haut niveau   | bas niveau        |
# | typage dynamique | typage statique |
# | syntaxe lisible et simple à utiliser |syntaxe moins lisible et plus ardue |
# | pas le plus rapide | parmi les plus rapides |
#
#
# Le noyau de Python est écrit en C

# %% [markdown]
# # Python ?
#
# En 2025 Python est indéniablement devenu un langage très populaire, très utilisé et beaucoup enseigné
#
# <small>[https://spectrum.ieee.org/the-top-programming-languages-2025](https://spectrum.ieee.org/the-top-programming-languages-2025)</small>
#
# ![top IEEE 2023](../img/ieee-top-languages-2025.png)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Ce qui a fait le succès de Python, amha, c’est la qualité et la diversité des bibliothèques (*libraries*) et des packages de la communauté Open Source
#
# En particulier dans les domaines suivants :
#  - Calcul scientifique
#  - Manipulations et visualisation de données / *data science*
#  - *Machine learning*
#  - Traitement Automatique des Langues (TAL) / *NLP*
#  - Développement web
#  - Traitement d’images et de données audio 🙂

# %% [markdown]
# ## Calcul scientifique
#
#  - [NumPy](https://numpy.org/) (Numerical Python)
#  Manipulation de tableaux à n dimensions (matrices)
#  Algèbre linéaire, calcul matriciel
#  - [SciPy](https://scipy.org/)
#  Implémentation d’algorithmes pour le calcul scientifique (dont le traitement du signal)
#  Repose sur NumPy
#
#  Ces deux bibliothèques sont écrites en Python, C/C++ et Fortran

# %% [markdown]
# ## Manipulations et visualisations de données
#
# - [Pandas](https://pandas.pydata.org/)
#  Manipulation et analyse de données tabulaires
# - [MatPlotLib](https://matplotlib.org/)
#  Visualisations de données
#  Combinée avec NumPy et SciPy, cette suite concurrence Matlab
# - [Seaborn](https://seaborn.pydata.org/)
#  Visualisations de données

# %% [markdown]
# ## *Machine learning*
#
# - [scikit-learn](https://scikit-learn.org/stable/)
#   Propose l’implémentation de beaucoup de méthodes d’apprentissage automatique (classification, clustering, …)
# - [TensorFlow](https://www.tensorflow.org/?hl=fr)
# - [PyTorch](https://pytorch.org/)
# - [Keras](https://keras.io/)
#   Deep Learning pour ces 3 dernières
# - [Hugging Face](https://huggingface.co/)

# %% [markdown]
# ## TAL / *NLP*
#
# - [NLTK](https://www.nltk.org/)
# - [Stanza](https://stanfordnlp.github.io/stanza/)
# - [Spacy](https://spacy.io/)
#
# Traitement de données langagières, des textes surtout, avec reconnaissance des parties du discours, des entités nommées, analyse syntaxe, analyse de sentiment, …

# %%
# !python -m spacy download fr_core_news_md

# %%
import spacy
from spacy import displacy

nlp = spacy.load('fr_core_news_md')
doc = nlp("Recevant mercredi le secrétaire général de l’OTAN, Mark Rutte, Donald Trump a exhibé des plans devant les journalistes. Non pas des combats en cours en Ukraine, mais de la salle de bal. ")
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Recevant mercredi le secrétaire général de l’
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OTAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Rutte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
# ...

# %%
displacy.render(doc, style="dep", jupyter=True, options={"distance":90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="c08033fcf9aa4546a12d2418f54c8e80-0" class="displacy" width="3020" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Recevant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">mercredi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %% [markdown]
# ## Développement web
#
# - [Django](https://www.djangoproject.com/)
# - [Flask](https://flask.palletsprojects.com/en/2.3.x/)
# - [FastAPI](https://fastapi.tiangolo.com/)
# - [BeautifulSoup](https://beautiful-soup-4.readthedocs.io/en/latest/)
#  Permet d’extraire des données depuis des pages HTML ou des fichiers XML

# %% [markdown]
# ## Traitement d’images et de données audio
#
# - Traitement d’images
#  - [Pillow](https://python-pillow.org/)
#  - [OpenCV](https://opencv.org/)
# - Traitement de données audio
#  - [pydub](http://pydub.com/)
#  - [librosa](https://librosa.org/)
